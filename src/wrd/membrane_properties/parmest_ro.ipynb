# %% [markdown]
# ___
# # Conducting a Parameter Estimation
# ___
#
# Author: Chenyu Wang
#
# For this demonstration, we will be going through how to set up a parameter estimation using the Pyomo tool ***parmest***. This simple case study aims to validate the reverse osmosis model by the real plant data.

# %% [markdown]
# ### Step 1: Imports
# Import all Pyomo, WaterTAP and helper modules needed for building and solving the parameter estimation problem.

# %%
# Imports from Pyomo
from pyomo.environ import (
    ConcreteModel,
    TerminationCondition,
    value,
    Reals,
    TransformationFactory,
    assert_optimal_termination,
    units as pyunits,
)
from pyomo.network import Arc
import pyomo.contrib.parmest.parmest as parmest  # to perform the parameter estimation

# Imports from IDAES
from idaes.core import FlowsheetBlock
from idaes.models.unit_models import Feed, Separator
from idaes.core.util.initialization import propagate_state
from idaes.core.util.model_statistics import degrees_of_freedom
import idaes.core.util.scaling as iscale
import idaes.logger as idaeslog

# Imports from WaterTAP
from watertap.unit_models.reverse_osmosis_0D import (
    ReverseOsmosis0D as RO,
    ConcentrationPolarizationType,
    MassTransferCoefficient,
)
from watertap.property_models import seawater_prop_pack as props
from watertap.core.solvers import get_solver  # to bring in ipopt solver

# Other imports
import pandas as pd  # to create a pandas dataframe to organize the data

pd.options.mode.chained_assignment = None
import numpy as np  # to manipulate the data into a usable format
import matplotlib.pyplot as plt  # to plot the results
# from utility_functions import load_data
import logging

logging.getLogger("pyomo").setLevel(logging.CRITICAL)
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Step 2: Gather and prepare the data
# *How does data need to be formatted for parmest?*
#
#
# - **Pandas Dataframe:** each column is an observed quantity (temperature, concentration, vapor pressure, etc.), each row is a distinct scenario (25, 0.02, 31.33)
#
# **Other options:**
# - **List of dictionaries:** each entry of the list is a distinct scenario, each key an observed quantity
# - **List of json file names:** each entry of the list contains a json file with the distinct scenario (for large datasets in parallel computing)
#
# In this tutorial, we use the data collected from a pilot plan of **Orange County Water District (OCWD)** for a RO unit.

# %%
# Read in xlsx file to pd.dataframe
data = pd.read_csv("WRD_Data_PRO1.csv")
# raw_data = pd.read_excel(r"Plant_data.xlsx")
# Prepare the data
# data, full_data = load_data(raw_data)
display(data)
# Out:
#        DateTime stage 1 feed conductivity (us/cm) stage 1 feed pressure (psi)  \
# 0      2/7/2019                       1106.280029                 25.14999962
# 1     2/27/2019                       1314.809937                 67.94999695
# 2     2/28/2019                       1263.189941                  105.409996
# 3      3/7/2019                       1026.199951                          70
# 4      3/9/2019                              1057                 97.18000031
# ...         ...                               ...                         ...
# 1707  7/27/2024                       1112.549927                 124.2699966
# 1708  7/28/2024                        1076.48999                 127.0499954
# 1709  7/29/2024                        1048.73999                 126.6999969
# 1710  7/30/2024                       1070.109985                 13.50999928
# 1711  7/31/2024                       1090.069946                 13.78999996
#
#      stage 1 permeate flowrate (gpm) stage 1 permeate conductivity (us/cm)  \
# 0                        763.1300049                                     0
# 1                        1437.959961                                     0
# 2                        1760.179932                                     0
# 3                        1066.599976                                    24
# 4                        1600.140015                                    26
# ...                              ...                                   ...
# 1707                     1817.689941                           39.02999878
# 1708                     1876.469971                                    38
# 1709                     1842.640015                           37.02999878
# 1710                     0.439999998                           137.9700012
# 1711                     0.669999957                           125.0299988
#
#      stage 1 concentrate flowrate (gpm) stage 1 concentrate pressure (psi)  \
# 0                           615.1599731                        24.76999855
# 1                           955.1999817                        66.26999664
# 2                           1125.509979                        102.7699966
# 3                           878.3799744                        62.44999695
# 4                           1225.159973                        84.15000153
# ...                                 ...                                ...
# 1707                        801.3999634                        115.2599945
# 1708                        801.6599731                        118.1800003
# 1709                        783.4499817                        117.6899948
# 1710                        0.359999981                        13.65999985
# 1711                        0.419999979                        13.94999981
#
#       Unnamed: 7  stage2_ro_inlet_P (psi)  stage2_ro_outlet_P (psi)  \
# 0            NaN                      NaN                       NaN
# 1            NaN                      NaN                       NaN
# 2            NaN                      NaN                       NaN
# 3            NaN                      NaN                       NaN
# 4            NaN                      NaN                       NaN
# ...          ...                      ...                       ...
# 1707         NaN                      NaN                       NaN
# 1708         NaN                      NaN                       NaN
# 1709         NaN                      NaN                       NaN
# 1710         NaN                      NaN                       NaN
# 1711         NaN                      NaN                       NaN
#
#       stage2_feed_conductivity (us/cm)  stage2_perm_conductivity (us/cm)  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 1707                               NaN                               NaN
# 1708                               NaN                               NaN
# 1709                               NaN                               NaN
# 1710                               NaN                               NaN
# 1711                               NaN                               NaN
#
#       stage2_feed_flow (gpm)  stage2_perm_flow (gpm)  stage3_ro_inlet_P (psi)  \
# 0                        NaN                     NaN                      NaN
# 1                        NaN                     NaN                      NaN
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
# ...                      ...                     ...                      ...
# 1707                     NaN                     NaN                      NaN
# 1708                     NaN                     NaN                      NaN
# 1709                     NaN                     NaN                      NaN
# 1710                     NaN                     NaN                      NaN
# 1711                     NaN                     NaN                      NaN
#
#       stage3_ro_outlet_P (psi)  stage3_feed_conductivity (us/cm)  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
# ...                        ...                               ...
# 1707                       NaN                               NaN
# 1708                       NaN                               NaN
# 1709                       NaN                               NaN
# 1710                       NaN                               NaN
# 1711                       NaN                               NaN
#
#       stage3_perm_conductivity (us/cm)  stage3_feed_flow (gpm)  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                                  NaN                     NaN
# ...                                ...                     ...
# 1707                               NaN                     NaN
# 1708                               NaN                     NaN
# 1709                               NaN                     NaN
# 1710                               NaN                     NaN
# 1711                               NaN                     NaN
#
#       stage3_perm_flow (gpm)
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 1707                     NaN
# 1708                     NaN
# 1709                     NaN
# 1710                     NaN
# 1711                     NaN
#
# [1712 rows x 20 columns]

# %% [markdown]
# ### Add and Values that need to be calculated

# %%
# Convert all columns except DateTime to numeric
for col in data.columns:
    if col != "DateTime":
        data[col] = pd.to_numeric(data[col], errors='coerce')

# Do any required data cleaning
data_mask_date = (data["DateTime"].str.startswith("8/1")) & (data["DateTime"].str.contains("/2021"))
cleaned_data = data[data_mask_date].reset_index(drop=True)
data_mask_perm_flow = cleaned_data["stage 1 permeate flowrate (gpm)"] >= 1603
cleaned_data = cleaned_data[data_mask_perm_flow].reset_index(drop=True)

cleaned_data["stage 1 feed salinity (g/L)"] = cleaned_data["stage 1 feed conductivity (us/cm)"] * 0.0005 # Conversion factor
cleaned_data["stage 1 permeate salinity (g/L)"] = cleaned_data["stage 1 permeate conductivity (us/cm)"] * 0.0005
cleaned_data["stage 1 feed flowrate (gpm)"] = cleaned_data["stage 1 permeate flowrate (gpm)"] + cleaned_data["stage 1 concentrate flowrate (gpm)"]
display(cleaned_data)
# Out:
#     DateTime  stage 1 feed conductivity (us/cm)  stage 1 feed pressure (psi)  \
# 0  8/11/2021                        1077.169922                   144.389999
# 1  8/13/2021                        1094.020020                   143.289993
# 2  8/16/2021                         962.019959                   141.110001
# 3  8/17/2021                        1064.669922                   143.959992
# 4  8/18/2021                        1075.719971                   142.020004
#
#    stage 1 permeate flowrate (gpm)  stage 1 permeate conductivity (us/cm)  \
# 0                      1608.400024                              25.000000
# 1                      1637.250000                              25.969999
# 2                      1607.659912                              24.000000
# 3                      1604.239990                              26.000000
# 4                      1633.709961                              26.000000
#
#    stage 1 concentrate flowrate (gpm)  stage 1 concentrate pressure (psi)  \
# 0                         1049.279938                          131.699997
# 1                         1043.739990                          131.020004
# 2                         1039.359985                          128.789993
# 3                         1038.019989                          131.959992
# 4                         1029.359955                          130.199997
#
#    Unnamed: 7  stage2_ro_inlet_P (psi)  stage2_ro_outlet_P (psi)  ...  \
# 0         NaN                      NaN                       NaN  ...
# 1         NaN                      NaN                       NaN  ...
# 2         NaN                      NaN                       NaN  ...
# 3         NaN                      NaN                       NaN  ...
# 4         NaN                      NaN                       NaN  ...
#
#    stage2_perm_flow (gpm)  stage3_ro_inlet_P (psi)  stage3_ro_outlet_P (psi)  \
# 0                     NaN                      NaN                       NaN
# 1                     NaN                      NaN                       NaN
# 2                     NaN                      NaN                       NaN
# 3                     NaN                      NaN                       NaN
# 4                     NaN                      NaN                       NaN
#
#    stage3_feed_conductivity (us/cm)  stage3_perm_conductivity (us/cm)  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    stage3_feed_flow (gpm)  stage3_perm_flow (gpm)  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#    stage 1 feed salinity (g/L)  stage 1 permeate salinity (g/L)  \
# 0                     0.538585                         0.012500
# 1                     0.547010                         0.012985
# 2                     0.481010                         0.012000
# 3                     0.532335                         0.013000
# 4                     0.537860                         0.013000
#
#    stage 1 feed flowrate (gpm)
# 0                  2657.679962
# 1                  2680.989990
# 2                  2647.019897
# 3                  2642.259979
# 4                  2663.069916
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Step 3: Define the RO model for parameter estimation
# *What model are parameters being fit to?*
#
# ***Parmest*** requires a "model function" to be defined that takes in the data and returns a Pyomo model.
#
# Set up the Pyomo model defining:
# - Pyomo Vars or Params for each parameter (or 'theta') to be estimated
# - the model equation (a function of the observed data, i.e., permeate flow rate, mass fraction)
#
#
#
# For this example, the RO model we are proposing is defined as `ro_parmest` function:

# %%
# Set the solver
solver = get_solver()  # this will make the ipopt solver available

# Define global conversion factors
# psi_to_pascal = 6894.75  # Pressure conversion
# gpm_to_m3ps = 6.309e-005  # Vol. flow conversion

# %%
# Import the fuction that creates flowsheet
from wrd.membrane_properties.ro_memb_test import solve_ro_module
def ro_parmest(data):
    # Maybe add logic to check units
    Qin = data.iloc[0]["stage 1 feed flowrate (gpm)"]
    Cin = data.iloc[0]["stage 1 feed salinity (g/L)"]
    Pin = data.iloc[0]["stage 1 feed pressure (psi)"]
    Pout = data.iloc[0]["stage 1 concentrate pressure (psi)"]
    # print(Qin, Cin, Pin, Pout)
    m = solve_ro_module(Qin=Qin, Cin=Cin, Pin=Pin, Pout=Pout)

    return m

# %% [markdown]
# ### Step 4: Define a list of parameter names
#
# The variables to be estimated by parmest must be given as a list of strings of the variable names as they are defined in the `ro_parmest`.

# %%
# variables from model to be estimated
# required format: list with strings of param/var names
theta_names = ["fs.ro.unit.A_comp[0, 'H2O']", "fs.ro.unit.B_comp[0, 'NaCl']"]

# %% [markdown]
# ### Step 5: Define an objective function
#
# Now, we should define an objective function for the parameter estimation. This is the deviation between the observation and the prediction typically chosen to be the sum of squared errors.
#
# $$
# \sum_{i=0}^n (observation_i - prediction_i)^2
# $$

# %%
# Sum of Squared Errors function
def SSE(m, data):
    flow_vol_scale = 1 / 1e3  
    conc_mass_phase_comp_scale = 1 / 1e-2 # Scaling factors are inverse of magnitude of input value???
    expr = flow_vol_scale * (
        (
            float(data.iloc[0]["stage 1 permeate flowrate (gpm)"])
            - value(pyunits.convert(m.fs.ro.unit.mixed_permeate[0.0].flow_vol_phase["Liq"], pyunits.gal/pyunits.min))
        )
        ** 2
    ) + conc_mass_phase_comp_scale * (
        (
            float(data.iloc[0]["stage 1 permeate salinity (g/L)"])
            - value(pyunits.convert(m.fs.ro.unit.mixed_permeate[0.0].conc_mass_phase_comp["Liq", "NaCl"], pyunits.g / pyunits.L))
        )
        ** 2
    )
    print(float(data.iloc[0]["stage 1 permeate salinity (g/L)"])
            - value(pyunits.convert(m.fs.ro.unit.mixed_permeate[0.0].conc_mass_phase_comp["Liq", "NaCl"], pyunits.g / pyunits.L)))
    print(float(data.iloc[0]["stage 1 permeate flowrate (gpm)"])
            - value(pyunits.convert(m.fs.ro.unit.mixed_permeate[0.0].flow_vol_phase["Liq"], pyunits.gal/pyunits.min)))
    return expr

# %% [markdown]
# ### Step 6: Solve the parameter estimation problem
#
# Now, we have everything we need for parmest to solve the parameter estimation problem:
#
#     - ro_parmest
#     - data
#     - theta_names
#     - objective_function

# %% [markdown]
# #### Step 6a: Set up the problem
#
# Set up the parameter estimation problem by creating an instance of the parmest 'Estimator' object and feed it the required inputs.

# %%
# create an instance of the parmest estimator
pest = parmest.Estimator(ro_parmest, cleaned_data, theta_names, SSE, tee=False,solver_options={'bound_push':1e-8})
# Attempted Troubleshooting below by setting up intial guesses, but I think this is actually done automatically
# theta_guesses = pd.DataFrame(columns=theta_names)
# print(theta_guesses)
# theta_guesses.loc['fs.ro.unit.A_comp[0,H2O]'] = 7.66e-12
# theta_guesses.loc['fs.ro.unit.B_comp[0,NaCl]'] = 2.22e-8
# print(theta_guesses)
# Out:
# Empty DataFrame
# Columns: [fs.ro.unit.A_comp[0,H2O], fs.ro.unit.B_comp[0,NaCl]]
# Index: []
#                            fs.ro.unit.A_comp[0,H2O]  fs.ro.unit.B_comp[0,NaCl]
# fs.ro.unit.A_comp[0,H2O]               7.660000e-12               7.660000e-12
# fs.ro.unit.B_comp[0,NaCl]              2.220000e-08               2.220000e-08

# %%
pest.objective_at_theta(theta_values=theta_guesses, initialize_parmest_model=True)
# Out:
# Setting RO 1 operating conditions
# 2026-01-12 12:06:46 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 12:06:46 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 12:06:46 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 12:06:51 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 12:06:51 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 12:06:52 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 12:06:52 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 12:06:52 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.09e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.55e-12 1.06e-01  -1.0 6.10e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.5451199187928069e-12    5.5451199187928069e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.5451199187928069e-12    5.5451199187928069e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.000
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2657.680                      gpm
# Inlet Conc.                   538.585                       mg/L
# Brine Flow                    994.455                       gpm
# Product Flow                  1663.226                      gpm
# Recovery                      62.582                        %
# Rejection                     99.277                        %
# Perm Conc                     3.896                         mg/L
# Brine Conc                    1432.852                      mg/L
# ∆P                            -12.690                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.0086042965307868
# -54.825500163729885
# Setting RO 1 operating conditions
# 2026-01-12 12:06:53 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 12:06:54 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 12:06:54 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 12:07:00 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 12:07:01 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 12:07:01 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 12:07:02 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 12:07:02 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 12:07:02 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.09e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.55e-12 1.06e-01  -1.0 6.10e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.5451199187928069e-12    5.5451199187928069e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.5451199187928069e-12    5.5451199187928069e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.000
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2657.680                      gpm
# Inlet Conc.                   538.585                       mg/L
# Brine Flow                    994.455                       gpm
# Product Flow                  1663.226                      gpm
# Recovery                      62.582                        %
# Rejection                     99.277                        %
# Perm Conc                     3.896                         mg/L
# Brine Conc                    1432.852                      mg/L
# ∆P                            -12.690                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.0086042965307868
# -54.825500163729885
# Setting RO 1 operating conditions
# 2026-01-12 12:07:04 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 12:07:04 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 12:07:05 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 12:07:11 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 12:07:12 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 12:07:12 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 12:07:12 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 12:07:12 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 12:07:12 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.09e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.55e-12 1.06e-01  -1.0 6.10e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.5451199187928069e-12    5.5451199187928069e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.5451199187928069e-12    5.5451199187928069e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.003
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2657.680                      gpm
# Inlet Conc.                   538.585                       mg/L
# Brine Flow                    994.455                       gpm
# Product Flow                  1663.226                      gpm
# Recovery                      62.582                        %
# Rejection                     99.277                        %
# Perm Conc                     3.896                         mg/L
# Brine Conc                    1432.852                      mg/L
# ∆P                            -12.690                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.0086042965307868
# -54.825500163729885
# Setting RO 1 operating conditions
# 2026-01-12 12:07:15 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 12:07:16 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 12:07:16 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 12:07:22 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 12:07:23 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 12:07:24 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 12:07:24 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 12:07:24 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 12:07:24 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.06e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.49e-12 1.06e-01  -1.0 6.07e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.4878324107221488e-12    5.4878324107221488e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.4878324107221488e-12    5.4878324107221488e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.000
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2680.990                      gpm
# Inlet Conc.                   547.010                       mg/L
# Brine Flow                    1031.356                      gpm
# Product Flow                  1649.635                      gpm
# Recovery                      61.531                        %
# Rejection                     99.282                        %
# Perm Conc                     3.927                         mg/L
# Brine Conc                    1415.661                      mg/L
# ∆P                            -12.270                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.009057998843189276
# -12.384537008570533
# Setting RO 1 operating conditions
# 2026-01-12 12:07:27 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 12:07:27 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 12:07:27 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 12:07:33 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# ...
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.11e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.59e-12 1.06e-01  -1.0 6.13e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.5939697318763137e-12    5.5939697318763137e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.5939697318763137e-12    5.5939697318763137e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.002
# Total CPU secs in NLP function evaluations           =      0.001
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2642.260                      gpm
# Inlet Conc.                   532.335                       mg/L
# Brine Flow                    978.653                       gpm
# Product Flow                  1663.608                      gpm
# Recovery                      62.962                        %
# Rejection                     99.273                        %
# Perm Conc                     3.869                         mg/L
# Brine Conc                    1430.672                      mg/L
# ∆P                            -12.000                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.009130880173731768
# -59.36772715299503
# Setting RO 1 operating conditions
# 2026-01-12 12:09:03 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 12:09:03 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 12:09:04 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 12:09:10 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 12:09:11 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 12:09:11 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 12:09:11 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 12:09:11 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 12:09:11 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.10e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.57e-12 1.06e-01  -1.0 6.12e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.5651039332360597e-12    5.5651039332360597e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.5651039332360597e-12    5.5651039332360597e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.000
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2663.070                      gpm
# Inlet Conc.                   537.860                       mg/L
# Brine Flow                    1026.193                      gpm
# Product Flow                  1636.877                      gpm
# Recovery                      61.466                        %
# Rejection                     99.278                        %
# Perm Conc                     3.885                         mg/L
# Brine Conc                    1389.602                      mg/L
# ∆P                            -11.820                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.009115251506010516
# -3.167107951266871
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 pest.objective_at_theta(theta_values=theta_guesses, initialize_parmest_model=True)
#
# File c:\Users\rchurchi\AppData\Local\anaconda3\envs\flex_desal\lib\site-packages\pyomo\contrib\parmest\parmest.py:1163, in Estimator.objective_at_theta(self, theta_values, initialize_parmest_model)
#    1161 # check if we are using deprecated parmest
#    1162 if self.pest_deprecated is not None:
# -> 1163     return self.pest_deprecated.objective_at_theta(
#    1164         theta_values=theta_values,
#    1165         initialize_parmest_model=initialize_parmest_model,
#    1166     )
#    1168 if len(self.estimator_theta_names) == 0:
#    1169     pass  # skip assertion if model has no fitted parameters
#
# File c:\Users\rchurchi\AppData\Local\anaconda3\envs\flex_desal\lib\site-packages\pyomo\contrib\parmest\parmest.py:2354, in _DeprecatedEstimator.objective_at_theta(self, theta_values, initialize_parmest_model)
#    2351     if worststatus != pyo.TerminationCondition.infeasible:
#    2352         all_obj.append(list(thetvals.values()) + [obj])
# -> 2354 global_all_obj = task_mgr.allgather_global_data(all_obj)
#    2355 dfcols = list(theta_names) + ['obj']
#    2356 obj_at_theta = pd.DataFrame(data=global_all_obj, columns=dfcols)
#
# File c:\Users\rchurchi\AppData\Local\anaconda3\envs\flex_desal\lib\site-packages\pyomo\contrib\parmest\utils\mpi_utils.py:134, in ParallelTaskManager.allgather_global_data(self, local_data)
#     133 def allgather_global_data(self, local_data):
# --> 134     assert len(local_data) == len(self._local_map)
#     135     if not self._mpi_interface.have_mpi:
#     136         return list(local_data)
#
# AssertionError:

# %% [markdown]
# #### Step 6b: Solve the parameter estimation problem
#
# Solve the parameter estimation problem by calling theta_est. This will use the entire data set to perform the parameter estimation.
#
# There are additional options for solving and testing. Further details can be found in the [parmest documentation](https://pyomo.readthedocs.io/en/6.7.0/contributed_packages/parmest/index.html).

# %%
# solve the parameter estimation problem
obj, theta = pest.theta_est()
# Out:
# Setting RO 1 operating conditions
# 2026-01-12 11:53:16 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 11:53:17 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 11:53:17 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 11:53:23 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 11:53:24 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 11:53:24 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 11:53:25 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 11:53:25 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 11:53:25 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.05e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.48e-12 1.06e-01  -1.0 6.07e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.4816151617842479e-12    5.4816151617842479e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.4816151617842479e-12    5.4816151617842479e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.007
# Total CPU secs in NLP function evaluations           =      0.002
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2632.150                      gpm
# Inlet Conc.                   538.490                       mg/L
# Brine Flow                    920.302                       gpm
# Product Flow                  1711.848                      gpm
# Recovery                      65.036                        %
# Rejection                     99.270                        %
# Perm Conc                     3.931                         mg/L
# Brine Conc                    1532.820                      mg/L
# ∆P                            -11.750                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.009059473930264962
# -122.34803803745035
# Setting RO 1 operating conditions
# 2026-01-12 11:53:28 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 11:53:29 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 11:53:29 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 11:53:37 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 11:53:38 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 11:53:38 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 11:53:39 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 11:53:39 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 11:53:39 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.07e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.51e-12 1.06e-01  -1.0 6.09e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.5124793618688273e-12    5.5124793618688273e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.5124793618688273e-12    5.5124793618688273e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.006
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2643.130                      gpm
# Inlet Conc.                   538.525                       mg/L
# Brine Flow                    944.059                       gpm
# Product Flow                  1699.071                      gpm
# Recovery                      64.283                        %
# Rejection                     99.273                        %
# Perm Conc                     3.913                         mg/L
# Brine Conc                    1500.692                      mg/L
# ∆P                            -11.920                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.00908651477929939
# -97.74131737314269
# Setting RO 1 operating conditions
# 2026-01-12 11:53:42 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 11:53:42 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 11:53:42 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 11:53:50 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 11:53:51 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 11:53:51 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 11:53:51 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 11:53:51 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 11:53:52 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.04e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.46e-12 1.06e-01  -1.0 6.06e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.4580784336621946e-12    5.4580784336621946e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.4580784336621946e-12    5.4580784336621946e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.005
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2646.090                      gpm
# Inlet Conc.                   543.070                       mg/L
# Brine Flow                    939.484                       gpm
# Product Flow                  1706.607                      gpm
# Recovery                      64.495                        %
# Rejection                     99.274                        %
# Perm Conc                     3.944                         mg/L
# Brine Conc                    1522.413                      mg/L
# ∆P                            -12.080                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.00949648796233463
# -111.4267570499203
# Setting RO 1 operating conditions
# 2026-01-12 11:53:54 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 11:53:54 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 11:53:55 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 11:54:03 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 11:54:04 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 11:54:04 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 11:54:05 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 11:54:05 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 11:54:05 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.19e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.74e-12 1.06e-01  -1.0 6.21e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.7416293941514596e-12    5.7416293941514596e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.7416293941514596e-12    5.7416293941514596e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.006
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2675.950                      gpm
# Inlet Conc.                   527.670                       mg/L
# Brine Flow                    983.091                       gpm
# Product Flow                  1692.859                      gpm
# Recovery                      63.262                        %
# Rejection                     99.282                        %
# Perm Conc                     3.789                         mg/L
# Brine Conc                    1429.780                      mg/L
# ∆P                            -12.170                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.009650818346455672
# -69.1191207533941
# Setting RO 1 operating conditions
# 2026-01-12 11:54:07 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 11:54:07 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 11:54:08 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 11:54:16 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# ...
# 2026-01-12 11:58:49 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 11:58:50 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 11:58:50 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 11:58:50 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 11:58:50 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 11:58:51 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.01e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.41e-12 1.06e-01  -1.0 6.03e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.4094506651836127e-12    5.4094506651836127e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.4094506651836127e-12    5.4094506651836127e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.008
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2643.230                      gpm
# Inlet Conc.                   546.410                       mg/L
# Brine Flow                    986.118                       gpm
# Product Flow                  1657.112                      gpm
# Recovery                      62.693                        %
# Rejection                     99.273                        %
# Perm Conc                     3.970                         mg/L
# Brine Conc                    1457.947                      mg/L
# ∆P                            -11.590                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.010529725744698019
# -46.46246872760594
# Setting RO 1 operating conditions
# 2026-01-12 11:58:53 [INFO] idaes.init.fs.feed: Initialization Complete.
# 2026-01-12 11:58:53 [INFO] idaes.init.fs.ro.feed: Initialization Step Complete.
# 2026-01-12 11:58:53 [INFO] idaes.init.fs.ro.unit.feed_side: Initialization Complete
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.1,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.2,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.3,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.4,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.5,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.6,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.7,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.8,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,0.9,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,H2O] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.material_flow_dx[0.0,1.0,Liq,NaCl] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.0] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.1] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.2] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.3] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.4] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.5] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.6] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.7] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.8] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,0.9] has no initial value: setting to 0.0
# 2026-01-12 11:59:01 [INFO] idaes.watertap.core.util.initialization: variable fs.ro.unit.feed_side.pressure_dx[0.0,1.0] has no initial value: setting to 0.0
# 2026-01-12 11:59:02 [INFO] idaes.init.fs.ro.unit: Initialization Complete: optimal - Optimal Solution Found
# 2026-01-12 11:59:02 [INFO] idaes.init.fs.ro.product: Initialization Step Complete.
# 2026-01-12 11:59:02 [INFO] idaes.init.fs.ro.disposal: Initialization Step Complete.
# 2026-01-12 11:59:02 [INFO] idaes.init.fs.product: Initialization Complete.
# 2026-01-12 11:59:03 [INFO] idaes.init.fs.brine: Initialization Complete.
# ipopt-watertap: ipopt with user variable scaling and IDAES jacobian constraint scaling
# Ipopt 3.13.2: tol=1e-08
# constr_viol_tol=1e-08
# acceptable_constr_viol_tol=1e-08
# bound_relax_factor=0.0
# honor_original_bounds=no
# nlp_scaling_method=user-scaling
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma27.
#
# Number of nonzeros in equality constraint Jacobian...:     1786
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      688
#
# Total number of variables............................:      633
#                      variables with only lower bounds:      178
#                 variables with lower and upper bounds:      369
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      633
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 6.09e-03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 5.54e-12 1.06e-01  -1.0 6.10e-03    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 1
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   5.5448978741878818e-12    5.5448978741878818e-12
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   5.5448978741878818e-12    5.5448978741878818e-12
#
#
# Number of objective function evaluations             = 2
# Number of objective gradient evaluations             = 2
# Number of equality constraint evaluations            = 2
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 2
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.005
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.
#
# ======================================= RO Report =======================================
#
# Parameter                     Value                         Units
# ------------------------------------------------------------------------------------------
# Inlet Flow                    2607.940                      gpm
# Inlet Conc.                   528.235                       mg/L
# Brine Flow                    1027.858                      gpm
# Product Flow                  1580.083                      gpm
# Recovery                      60.587                        %
# Rejection                     99.262                        %
# Perm Conc                     3.896                         mg/L
# Brine Conc                    1334.279                      mg/L
# ∆P                            -11.470                       psi
# Membrane Area                 18648.000                     m**2
# Membrane Width                1332.000                      m
# Membrane Length               7.000                         m
# Perm Backpressure             20.000                        psi
# 0.010104131382108302
# -2.482569152139604

# %%
# display results
print("theta:\n", theta)
print("Objective function value:", obj)
# Out:
# theta:
#  fs.ro.unit.A_comp[0.0,H2O]     1.252812e-12
# fs.ro.unit.B_comp[0.0,NaCl]    5.593753e-06
# dtype: float64
# Objective function value: 5.62429600422016

# %% [markdown]
# ### Step 7: Visualize results
#
# Finally, we can visualize the results using ***matplotlib*** to create a plot of the data and the parameter estimatation fit.

# %% [markdown]
# #### Step 7.1: Define the model with the optimal parameters

# %%
def ro_opt():
    # Build the flowsheet
    m = ConcreteModel()
    m.fs = FlowsheetBlock(dynamic=False)
    m.fs.properties = props.SeawaterParameterBlock()
    m.fs.feed = Feed(property_package=m.fs.properties)
    m.fs.RO = RO(
        property_package=m.fs.properties,
        has_pressure_change=True,
        concentration_polarization_type=ConcentrationPolarizationType.none,
        mass_transfer_coefficient=MassTransferCoefficient.none,
    )

    m.fs.s00 = Arc(source=m.fs.feed.outlet, destination=m.fs.RO.inlet)
    TransformationFactory("network.expand_arcs").apply_to(m)

    # Set initial conditions
    m.fs.feed.properties[0].flow_vol_phase.fix(gpm_to_m3ps * 8)
    m.fs.feed.properties[0].temperature.fix(273.15 + 25)
    m.fs.feed.properties[0].pressure.fix(psi_to_pascal * 188)
    m.fs.feed.properties[0].mass_frac_phase_comp["Liq", "TDS"].fix(0.001)

    m.fs.RO.area.fix(28.8)  # Data is for 4 membrane elements
    m.fs.RO.permeate.pressure[0].fix(101325)
    m.fs.RO.deltaP.fix(-psi_to_pascal * 24.6)

    # Set optimal values of parameters from parmest
    m.fs.RO.A_comp[0, "H2O"].fix(theta.iloc[0])
    m.fs.RO.B_comp[0, "TDS"].fix(theta.iloc[1])

    # Set scaling factors
    m.fs.properties.set_default_scaling(
        "flow_mass_phase_comp", 1e1, index=("Liq", "H2O")
    )
    m.fs.properties.set_default_scaling(
        "flow_mass_phase_comp", 1e6, index=("Liq", "TDS")
    )
    iscale.set_scaling_factor(m.fs.RO.area, 1e-1)
    iscale.calculate_scaling_factors(m)

    # Initialize the system
    solver.solve(m.fs.feed)
    propagate_state(m.fs.s00)
    m.fs.RO.initialize(outlvl=idaeslog.ERROR)

    assert degrees_of_freedom(m) == 0

    return m

# %% [markdown]
# #### Step 7.2: Create a table to save model results

# %%
# Create a new table to save model results
model_results = full_data.copy()
m = ro_opt()
for i in range(model_results.shape[0]):
    # Conversion factors
    psi_to_pascal = 6894.75  # Pressure conversion
    gpm_to_m3ps = 6.309e-005  # Vol. flow conversion

    # Update operating conditions
    m.fs.feed.properties[0].flow_vol_phase.fix(
        gpm_to_m3ps * float(model_results.iloc[i]["flow_vol_in"])
    )
    m.fs.feed.properties[0].pressure.fix(
        psi_to_pascal * float(model_results.iloc[i]["pressure_in"])
    )
    m.fs.feed.properties[0].mass_frac_phase_comp["Liq", "TDS"].fix(
        float(model_results.iloc[i]["mass_frac_TDS_in"])
    )
    m.fs.RO.deltaP.fix(-psi_to_pascal * float(model_results.iloc[i]["deltaP"]))

    results = solver.solve(m, tee=False)
    assert_optimal_termination(results)

    model_results.iloc[i, 5] = (
        value(m.fs.RO.mixed_permeate[0.0].flow_vol_phase["Liq"]) / gpm_to_m3ps
    )
    model_results.iloc[i, 6] = (
        value(m.fs.RO.mixed_permeate[0.0].mass_frac_phase_comp["Liq", "TDS"]) / 1e-6
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 2
#       1 # Create a new table to save model results
# ----> 2 model_results = full_data.copy()
#       3 m = ro_opt()
#       4 for i in range(model_results.shape[0]):
#       5     # Conversion factors
#
# NameError: name 'full_data' is not defined

# %% [markdown]
# #### Step 7.3: Visualize model vs data comparison

# %%
plt.figure()
plt.scatter(
    full_data.index, full_data["flow_vol_permeate"], label="Data", color="red", s=15
)
plt.plot(model_results.index, model_results["flow_vol_permeate"], label="Model")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure()
plt.scatter(
    full_data.index,
    full_data["mass_frac_TDS_permeate"],
    label="Data",
    color="red",
    s=15,
)
plt.plot(model_results.index, model_results["mass_frac_TDS_permeate"], label="Model")
plt.legend()
plt.grid(True)
plt.show()
